# %%
import os
for item in os.environ:
    print(f'{item}{" : "}{os.environ[item]}')
# Out:
# ALLUSERSPROFILE : C:\ProgramData
# APPDATA : C:\Users\masri\AppData\Roaming
# ASL.LOG : Destination=file
# CHOCOLATEYINSTALL : C:\ProgramData\chocolatey
# CHOCOLATEYLASTPATHUPDATE : 132800167913167543
# CLISP : C:\clisp-2.49\clisp.exe
# COMMONPROGRAMFILES : C:\Program Files\Common Files
# COMMONPROGRAMFILES(X86) : C:\Program Files (x86)\Common Files
# COMMONPROGRAMW6432 : C:\Program Files\Common Files
# COMPUTERNAME : DESKTOP-FV5K7VN
# COMSPEC : C:\WINDOWS\system32\cmd.exe
# CONFIGSETROOT : C:\WINDOWS\ConfigSetRoot
# DRIVERDATA : C:\Windows\System32\Drivers\DriverData
# HOMEDRIVE : C:
# HOMEPATH : \Users\masri
# IDEA_INITIAL_DIRECTORY : C:\Users\masri\AppData\Local\JetBrains\Toolbox\apps\PyCharm-P\ch-0\221.5080.212\bin
# LANG : en_US.UTF-8
# LANGUAGE :
# LC_ALL : en_US.UTF-8
# LOCALAPPDATA : C:\Users\masri\AppData\Local
# LOGONSERVER : \\DESKTOP-FV5K7VN
# NUMBER_OF_PROCESSORS : 12
# ONEDRIVE : C:\Users\masri\OneDrive
# ONEDRIVECONSUMER : C:\Users\masri\OneDrive
# OS : Windows_NT
# PATH : E:\Repo\PycharmProjects\Data_communication_and_networking\venv\Scripts;C:\Program Files (x86)\VMware\VMware Workstation\bin\;C:\Program Files\Common Files\Oracle\Java\javapath;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\Program Files\Microsoft\jdk-11.0.12.7-hotspot\bin;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR;C:\Program Files\Git\cmd;C:\Program Files\Microsoft SQL Server\150\Tools\Binn\;C:\Program Files\Microsoft SQL Server\Client SDK\ODBC\170\Tools\Binn\;C:\Program Files\dotnet\;C:\Program Files\CMake\bin;C:\Program Files\nodejs\;C:\ProgramData\chocolatey\bin;;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files (x86)\Calibre2\;C:\Program Files\Docker\Docker\resources\bin;C:\ProgramData\DockerDesktop\version-bin;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files (x86)\Steel Bank Common Lisp\;C:\Program Files\MySQL\MySQL Shell 8.0\bin\;C:\Users\masri\AppData\Local\Microsoft\WindowsApps;C:\Users\masri\AppData\Local\GitHubDesktop\bin;C:\Users\masri\.dotnet\tools;C:\Users\masri\AppData\Local\Programs\Microsoft VS Code\bin;C:\Users\masri\AppData\Roaming\npm;C:\Users\masri\AppData\Local\atom\bin;C:\Python310;C:\Python310\Tools\scripts;C:\Users\masri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts;C:\Users\masri\.android\avd;C:\Users\masri\AppData\Local\Microsoft\WindowsApps;C:\Users\masri\.dotnet\tools;C:\Program Files (x86)\Steel Bank Common Lisp\sbcl.exe
# PATHEXT : .COM;.EXE;.BAT;.CMD;.VBS;.VBE;.JS;.JSE;.WSF;.WSH;.MSC
# PIP : C:\Python310\Scripts\pip
# PROCESSOR_ARCHITECTURE : AMD64
# PROCESSOR_IDENTIFIER : AMD64 Family 25 Model 33 Stepping 0, AuthenticAMD
# PROCESSOR_LEVEL : 25
# PROCESSOR_REVISION : 2100
# PROGRAMDATA : C:\ProgramData
# PROGRAMFILES : C:\Program Files
# PROGRAMFILES(X86) : C:\Program Files (x86)
# PROGRAMW6432 : C:\Program Files
# PROMPT : (venv) $P$G
# PSMODULEPATH : %ProgramFiles%\WindowsPowerShell\Modules;C:\WINDOWS\system32\WindowsPowerShell\v1.0\Modules
# PUBLIC : C:\Users\Public
# PYTHONPATH : E:\Repo\PycharmProjects\Data_communication_and_networking
# PYTHONUSERBASE : C:\Users\masri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages
# SESSIONNAME : Console
# SYSTEMDRIVE : C:
# SYSTEMROOT : C:\WINDOWS
# TEMP : C:\Users\masri\AppData\Local\Temp
# TMP : C:\Users\masri\AppData\Local\Temp
# TOOLBOX_VERSION : 1.23.11731
# USERDOMAIN : DESKTOP-FV5K7VN
# USERDOMAIN_ROAMINGPROFILE : DESKTOP-FV5K7VN
# USERNAME : masri
# USERPROFILE : C:\Users\masri
# VBOX_HWVIRTEX_IGNORE_SVM_IN_USE : 1
# VBOX_MSI_INSTALL_PATH : D:\Installed\Virtual Box\
# VIRTUAL_ENV : E:\Repo\PycharmProjects\Data_communication_and_networking\venv
# VS160COMCOMNTOOLS : C:\Program Files (x86)\Microsoft Visual Studio\2019\Community\Common7\Tools\
# WINDIR : C:\WINDOWS
# _OLD_VIRTUAL_PATH : C:\Program Files (x86)\VMware\VMware Workstation\bin\;C:\Program Files\Common Files\Oracle\Java\javapath;C:\Program Files (x86)\Common Files\Oracle\Java\javapath;C:\Program Files\Microsoft\jdk-11.0.12.7-hotspot\bin;C:\Windows\system32;C:\Windows;C:\Windows\System32\Wbem;C:\Windows\System32\WindowsPowerShell\v1.0\;C:\Windows\System32\OpenSSH\;C:\Program Files (x86)\NVIDIA Corporation\PhysX\Common;C:\Program Files\NVIDIA Corporation\NVIDIA NvDLISR;C:\Program Files\Git\cmd;C:\Program Files\Microsoft SQL Server\150\Tools\Binn\;C:\Program Files\Microsoft SQL Server\Client SDK\ODBC\170\Tools\Binn\;C:\Program Files\dotnet\;C:\Program Files\CMake\bin;C:\Program Files\nodejs\;C:\ProgramData\chocolatey\bin;;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files (x86)\Calibre2\;C:\Program Files\Docker\Docker\resources\bin;C:\ProgramData\DockerDesktop\version-bin;C:\WINDOWS\system32;C:\WINDOWS;C:\WINDOWS\System32\Wbem;C:\WINDOWS\System32\WindowsPowerShell\v1.0\;C:\WINDOWS\System32\OpenSSH\;C:\Program Files (x86)\Steel Bank Common Lisp\;C:\Program Files\MySQL\MySQL Shell 8.0\bin\;C:\Users\masri\AppData\Local\Microsoft\WindowsApps;C:\Users\masri\AppData\Local\GitHubDesktop\bin;C:\Users\masri\.dotnet\tools;C:\Users\masri\AppData\Local\Programs\Microsoft VS Code\bin;C:\Users\masri\AppData\Roaming\npm;C:\Users\masri\AppData\Local\atom\bin;C:\Python310;C:\Python310\Tools\scripts;C:\Users\masri\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\Scripts;C:\Users\masri\.android\avd;C:\Users\masri\AppData\Local\Microsoft\WindowsApps;C:\Users\masri\.dotnet\tools;C:\Program Files (x86)\Steel Bank Common Lisp\sbcl.exe
# _OLD_VIRTUAL_PROMPT : $P$G
# PYDEVD_USE_FRAME_EVAL : NO
# JPY_INTERRUPT_EVENT : 1788
# IPY_INTERRUPT_EVENT : 1788
# JPY_PARENT_PID : 1256
# TERM : xterm-color
# CLICOLOR : 1
# PAGER : cat
# GIT_PAGER : cat
# MPLBACKEND : module://matplotlib_inline.backend_inline

# %%
import psutil
import platform
from datetime import datetime
# import cpuinfo
import socket
import uuid
import re


def get_size(bytes, suffix="B"):
    """
    Scale bytes to its proper format
    e.g:
        1253656 => '1.20MB'
        1253656678 => '1.17GB'
    """
    factor = 1024
    for unit in ["", "K", "M", "G", "T", "P"]:
        if bytes < factor:
            return f"{bytes:.2f}{unit}{suffix}"
        bytes /= factor

def System_information():
    print("="*40, "System Information", "="*40)
    uname = platform.uname()
    print(f"System: {uname.system}")
    print(f"Node Name: {uname.node}")
    print(f"Release: {uname.release}")
    print(f"Version: {uname.version}")
    print(f"Machine: {uname.machine}")
    print(f"Processor: {uname.processor}")
    # print(f"Processor: {cpuinfo.get_cpu_info()['brand_raw']}")
    print(f"Ip-Address: {socket.gethostbyname(socket.gethostname())}")
    print(f"Mac-Address: {':'.join(re.findall('..', '%012x' % uuid.getnode()))}")


    # Boot Time
    print("="*40, "Boot Time", "="*40)
    boot_time_timestamp = psutil.boot_time()
    bt = datetime.fromtimestamp(boot_time_timestamp)
    print(f"Boot Time: {bt.year}/{bt.month}/{bt.day} {bt.hour}:{bt.minute}:{bt.second}")


    # print CPU information
    print("="*40, "CPU Info", "="*40)
    # number of cores
    print("Physical cores:", psutil.cpu_count(logical=False))
    print("Total cores:", psutil.cpu_count(logical=True))
    # CPU frequencies
    cpufreq = psutil.cpu_freq()
    print(f"Max Frequency: {cpufreq.max:.2f}Mhz")
    print(f"Min Frequency: {cpufreq.min:.2f}Mhz")
    print(f"Current Frequency: {cpufreq.current:.2f}Mhz")
    # CPU usage
    print("CPU Usage Per Core:")
    for i, percentage in enumerate(psutil.cpu_percent(percpu=True, interval=1)):
        print(f"Core {i}: {percentage}%")
    print(f"Total CPU Usage: {psutil.cpu_percent()}%")


    # Memory Information
    print("="*40, "Memory Information", "="*40)
    # get the memory details
    svmem = psutil.virtual_memory()
    print(f"Total: {get_size(svmem.total)}")
    print(f"Available: {get_size(svmem.available)}")
    print(f"Used: {get_size(svmem.used)}")
    print(f"Percentage: {svmem.percent}%")



    print("="*20, "SWAP", "="*20)
    # get the swap memory details (if exists)
    swap = psutil.swap_memory()
    print(f"Total: {get_size(swap.total)}")
    print(f"Free: {get_size(swap.free)}")
    print(f"Used: {get_size(swap.used)}")
    print(f"Percentage: {swap.percent}%")



    # Disk Information
    print("="*40, "Disk Information", "="*40)
    print("Partitions and Usage:")
    # get all disk partitions
    partitions = psutil.disk_partitions()
    for partition in partitions:
        print(f"=== Device: {partition.device} ===")
        print(f"  Mountpoint: {partition.mountpoint}")
        print(f"  File system type: {partition.fstype}")
        try:
            partition_usage = psutil.disk_usage(partition.mountpoint)
        except PermissionError:
            # this can be catched due to the disk that
            # isn't ready
            continue
        print(f"  Total Size: {get_size(partition_usage.total)}")
        print(f"  Used: {get_size(partition_usage.used)}")
        print(f"  Free: {get_size(partition_usage.free)}")
        print(f"  Percentage: {partition_usage.percent}%")
    # get IO statistics since boot
    disk_io = psutil.disk_io_counters()
    print(f"Total read: {get_size(disk_io.read_bytes)}")
    print(f"Total write: {get_size(disk_io.write_bytes)}")

    ## Network information
    print("="*40, "Network Information", "="*40)
    ## get all network interfaces (virtual and physical)
    if_addrs = psutil.net_if_addrs()
    for interface_name, interface_addresses in if_addrs.items():
        for address in interface_addresses:
            print(f"=== Interface: {interface_name} ===")
            if str(address.family) == 'AddressFamily.AF_INET':
                print(f"  IP Address: {address.address}")
                print(f"  Netmask: {address.netmask}")
                print(f"  Broadcast IP: {address.broadcast}")
            elif str(address.family) == 'AddressFamily.AF_PACKET':
                print(f"  MAC Address: {address.address}")
                print(f"  Netmask: {address.netmask}")
                print(f"  Broadcast MAC: {address.broadcast}")
    ##get IO statistics since boot
    net_io = psutil.net_io_counters()
    print(f"Total Bytes Sent: {get_size(net_io.bytes_sent)}")
    print(f"Total Bytes Received: {get_size(net_io.bytes_recv)}")


if __name__ == "__main__":

    System_information()
# Out:
# ======================================== System Information ========================================
# System: Windows
# Node Name: DESKTOP-FV5K7VN
# Release: 10
# Version: 10.0.22598
# Machine: AMD64
# Processor: AMD64 Family 25 Model 33 Stepping 0, AuthenticAMD
# Ip-Address: 128.172.44.223
# Mac-Address: 22:4e:f6:f0:b4:fb
# ======================================== Boot Time ========================================
# Boot Time: 2022/4/17 13:17:51
# ======================================== CPU Info ========================================
# Physical cores: 6
# Total cores: 12
# Max Frequency: 3701.00Mhz
# Min Frequency: 0.00Mhz
# Current Frequency: 3701.00Mhz
# CPU Usage Per Core:
# Core 0: 4.6%
# Core 1: 1.5%
# Core 2: 1.5%
# Core 3: 0.0%
# Core 4: 13.8%
# Core 5: 1.5%
# Core 6: 1.6%
# Core 7: 1.5%
# Core 8: 3.1%
# Core 9: 0.0%
# Core 10: 28.8%
# Core 11: 1.5%
# Total CPU Usage: 1.1%
# ======================================== Memory Information ========================================
# Total: 15.92GB
# Available: 6.01GB
# Used: 9.90GB
# Percentage: 62.2%
# ==================== SWAP ====================
# Total: 7.02GB
# Free: -2195628032.00B
# Used: 9.06GB
# Percentage: 129.1%
# ======================================== Disk Information ========================================
# Partitions and Usage:
# === Device: C:\ ===
#   Mountpoint: C:\
#   File system type: NTFS
#   Total Size: 464.44GB
#   Used: 359.51GB
#   Free: 104.93GB
#   Percentage: 77.4%
# === Device: D:\ ===
#   Mountpoint: D:\
#   File system type: exFAT
#   Total Size: 12.73TB
#   Used: 1.17TB
#   Free: 11.56TB
#   Percentage: 9.2%
# === Device: E:\ ===
#   Mountpoint: E:\
#   File system type: exFAT
#   Total Size: 1.82TB
#   Used: 367.34GB
#   Free: 1.46TB
#   Percentage: 19.7%
# === Device: G:\ ===
#   Mountpoint: G:\
#   File system type: FAT32
#   Total Size: 464.44GB
#   Used: 364.76GB
#   Free: 99.68GB
#   Percentage: 78.5%
# === Device: H:\ ===
#   Mountpoint: H:\
#   File system type: FAT32
#   Total Size: 15.00GB
#   Used: 3.85GB
#   Free: 11.15GB
#   Percentage: 25.7%
# Total read: 126.39GB
# Total write: 271.35GB
# ======================================== Network Information ========================================
# === Interface: Ethernet 2 ===
# === Interface: Ethernet 2 ===
#   IP Address: 128.172.44.223
#   Netmask: 255.255.0.0
#   Broadcast IP: None
# === Interface: Ethernet 2 ===
# === Interface: Ethernet 2 ===
# === Interface: Local Area Connection* 1 ===
# === Interface: Local Area Connection* 1 ===
#   IP Address: 169.254.226.95
#   Netmask: 255.255.0.0
#   Broadcast IP: None
# === Interface: Local Area Connection* 1 ===
# === Interface: Local Area Connection* 2 ===
# === Interface: Local Area Connection* 2 ===
#   IP Address: 169.254.49.249
#   Netmask: 255.255.0.0
#   Broadcast IP: None
# === Interface: Local Area Connection* 2 ===
# === Interface: VMware Network Adapter VMnet1 ===
# === Interface: VMware Network Adapter VMnet1 ===
#   IP Address: 192.168.61.1
#   Netmask: 255.255.255.0
#   Broadcast IP: None
# === Interface: VMware Network Adapter VMnet1 ===
# === Interface: VMware Network Adapter VMnet8 ===
# === Interface: VMware Network Adapter VMnet8 ===
#   IP Address: 192.168.111.1
#   Netmask: 255.255.255.0
#   Broadcast IP: None
# === Interface: VMware Network Adapter VMnet8 ===
# === Interface: Wi-Fi ===
# === Interface: Wi-Fi ===
#   IP Address: 10.0.0.61
#   Netmask: 255.255.255.0
#   Broadcast IP: None
# === Interface: Wi-Fi ===
# === Interface: Wi-Fi ===
# === Interface: Wi-Fi ===
# === Interface: Wi-Fi ===
# === Interface: Bluetooth Network Connection ===
# === Interface: Bluetooth Network Connection ===
#   IP Address: 169.254.203.13
#   Netmask: 255.255.0.0
#   Broadcast IP: None
# === Interface: Bluetooth Network Connection ===
# === Interface: Ethernet ===
# === Interface: Ethernet ===
#   IP Address: 169.254.57.134
#   Netmask: 255.255.0.0
#   Broadcast IP: None
# === Interface: Ethernet ===
# === Interface: vEthernet (WSL) ===
# === Interface: vEthernet (WSL) ===
#   IP Address: 172.25.96.1
#   Netmask: 255.255.240.0
#   Broadcast IP: None
# === Interface: vEthernet (WSL) ===
# === Interface: vEthernet (Default Switch) ===
# === Interface: vEthernet (Default Switch) ===
#   IP Address: 172.24.32.1
#   Netmask: 255.255.240.0
#   Broadcast IP: None
# === Interface: vEthernet (Default Switch) ===
# === Interface: Loopback Pseudo-Interface 1 ===
#   IP Address: 127.0.0.1
#   Netmask: 255.0.0.0
#   Broadcast IP: None
# === Interface: Loopback Pseudo-Interface 1 ===
# Total Bytes Sent: 51.49MB
# Total Bytes Received: 132.28MB

# %%
socket.getfqdn()
# Out:
# 'DESKTOP-FV5K7VN.vcu.edu'

# %%
import os
os.getenv('HOSTNAME')

# %%
filename = '\yfff\yutyt\werewr'
print(filename)
if filename.startswith("\\"):
    print("asd")
# Out:
# \yfff\yutyt\werewr
# asd
